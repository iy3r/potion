# %%
# Setup path for databse

# %autoreload 2
from pathlib import Path
path = Path("./database/")

# %%
# Build/update flat-file(csv) database

from potion import Database

db = Database(path)
db.update()

# %%
# Create a slice of data from the database

from potion import Slice

s = Slice(path)

# %%
# Example

s.data.query('Symbol == "HDFCBANK"')
# Out:
#                Date    Symbol Underlying Log Returns (C) = LN(A/B)
# 583     19-JUN-2018  HDFCBANK                               0.0022
# 2279    18-JUN-2018  HDFCBANK                              -0.0052
# 3975    15-JUN-2018  HDFCBANK                              -0.0038
# 5663    14-JUN-2018  HDFCBANK                               0.0029
# 7351    13-JUN-2018  HDFCBANK                              -0.0061
# 9039    12-JUN-2018  HDFCBANK                               0.0008
# 10733   11-JUN-2018  HDFCBANK                              -0.0034
# 12430   08-JUN-2018  HDFCBANK                              -0.0063
# 14119   07-JUN-2018  HDFCBANK                               0.0024
# 15809   06-JUN-2018  HDFCBANK                               -0.003
# 17498   05-JUN-2018  HDFCBANK                               0.0085
# 19195   04-JUN-2018  HDFCBANK                              -0.0310
# 20896   01-JUN-2018  HDFCBANK                              -0.0136
# 22586   31-MAY-2018  HDFCBANK                               0.0499
# 24276   30-MAY-2018  HDFCBANK                               0.0077
# 25966   29-MAY-2018  HDFCBANK                              -0.0047
# 27660   28-MAY-2018  HDFCBANK                               0.0165
# 29358   25-MAY-2018  HDFCBANK                               0.0114
# 31047   24-MAY-2018  HDFCBANK                               0.0094
# 32736   23-MAY-2018  HDFCBANK                              -0.0113
# 34427   22-MAY-2018  HDFCBANK                              -0.0016
# 36121   21-MAY-2018  HDFCBANK                              -0.0095
# 37820   18-MAY-2018  HDFCBANK                              -0.0077
# 39510   17-MAY-2018  HDFCBANK                               0.0022
# 41200   16-MAY-2018  HDFCBANK                              -0.0071
# 42890   15-MAY-2018  HDFCBANK                               0.0079
# 44582   14-MAY-2018  HDFCBANK                                0.005
# 46279   11-MAY-2018  HDFCBANK                               0.0095
# 47969   10-MAY-2018  HDFCBANK                               0.0072
# 49659   09-MAY-2018  HDFCBANK                               0.0058
# ...             ...       ...                                  ...
# 366073  31-JUL-2017  HDFCBANK                               0.0033
# 367729  28-JUL-2017  HDFCBANK                              -0.0062
# 369369  27-JUL-2017  HDFCBANK                               0.0238
# 371006  26-JUL-2017  HDFCBANK                               0.0045
# 372643  25-JUL-2017  HDFCBANK                               0.0026
# 374280  24-JUL-2017  HDFCBANK                               0.0186
# 375931  21-JUL-2017  HDFCBANK                              -0.0046
# 377568  20-JUL-2017  HDFCBANK                               0.0109
# 379203  19-JUL-2017  HDFCBANK                               0.0052
# 380838  18-JUL-2017  HDFCBANK                               0.0007
# 382475  17-JUL-2017  HDFCBANK                               0.0014
# 384124  14-JUL-2017  HDFCBANK                              -0.0021
# 385760  13-JUL-2017  HDFCBANK                               0.0014
# 387397  12-JUL-2017  HDFCBANK                               0.0005
# 389034  11-JUL-2017  HDFCBANK                               0.0024
# 390671  10-JUL-2017  HDFCBANK                               0.0055
# 392318  07-JUL-2017  HDFCBANK                               0.0054
# 393953  06-JUL-2017  HDFCBANK                               0.0057
# 395588  05-JUL-2017  HDFCBANK                              -0.0028
# 397224  04-JUL-2017  HDFCBANK                              -0.0032
# 398862  03-JUL-2017  HDFCBANK                               0.0040
# 400509  30-JUN-2017  HDFCBANK                              -0.0066
# 402143  29-JUN-2017  HDFCBANK                               0.0046
# 403776  28-JUN-2017  HDFCBANK                              -0.0007
# 405412  27-JUN-2017  HDFCBANK                              -0.0066
# 407056  23-JUN-2017  HDFCBANK                              -0.0115
# 408688  22-JUN-2017  HDFCBANK                              -0.0004
# 410321  21-JUN-2017  HDFCBANK                               0.0072
# 411955  20-JUN-2017  HDFCBANK                              -0.0038
# 413592  19-JUN-2017  HDFCBANK                               0.0141
#
# [250 rows x 3 columns]
